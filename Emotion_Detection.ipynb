# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator  
from tensorflow.keras.utils import img_to_array, load_img
from keras.applications.mobilenet import MobileNet, preprocess_input 
from keras.losses import categorical_crossentropy

# %% [markdown]
# #  Building our Model To train the data

# %%
# Working with pre trained model 

base_model = MobileNet( input_shape=(224,224,3), include_top= False )

for layer in base_model.layers:
  layer.trainable = False


x = Flatten()(base_model.output)
x = Dense(units=7 , activation='softmax' )(x)

# creating our model.
model = Model(base_model.input, x)

# %%
model.compile(optimizer='adam', loss= categorical_crossentropy , metrics=['accuracy']  )

# %% [markdown]
# # Preparing our data using data generator

# %%
train_datagen = ImageDataGenerator(
     zoom_range = 0.2, 
     shear_range = 0.2, 
     horizontal_flip=True, 
     rescale = 1./255
)

train_data = train_datagen.flow_from_directory(directory= "./train/", 
                                               target_size=(224,224), 
                                               batch_size=32,
                                  )


train_data.class_indices
# Out:
# Found 350 images belonging to 7 classes.
# {'Angry': 0,
#  'Disguist': 1,
#  'Fear': 2,
#  'Happy': 3,
#  'Neutral': 4,
#  'Sad': 5,
#  'Surprise': 6}

# %%
val_datagen = ImageDataGenerator(rescale = 1./255 )

val_data = val_datagen.flow_from_directory(directory= "./train/", 
                                           target_size=(224,224), 
                                           batch_size=32,
                                  )
# Out:
# Found 350 images belonging to 7 classes.

# %% [markdown]
# # visualizaing the data that is fed to train data gen

# %%
# to visualize the images in the traing data denerator 

t_img , label = train_data.next()

#-----------------------------------------------------------------------------
# function when called will prot the images 
def plotImages(img_arr, label):
  """
  input  :- images array 
  output :- plots the images 
  """
  count = 0
  for im, l in zip(img_arr,label) :
    plt.imshow(im)
    plt.title(im.shape)
    plt.axis = False
    plt.show()
    
    count += 1
    if count == 10:
      break

#-----------------------------------------------------------------------------
# function call to plot the images 
plotImages(t_img, label)

# %% [markdown]
# # having early stopping and model check point

# %%
## having early stopping and model check point 

from keras.callbacks import ModelCheckpoint, EarlyStopping

# early stopping
es = EarlyStopping(monitor='val_accuracy', min_delta= 0.01 , patience= 5, verbose= 1, mode='auto')

# model check point
mc = ModelCheckpoint(filepath="best_model.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list 
call_back = [es, mc]

# %%
hist = model.fit_generator(train_data, 
                           steps_per_epoch= 10, 
                           epochs= 30, 
                           validation_data= val_data, 
                           validation_steps= 8, 
                           callbacks=[es,mc])
# Out:
# C:\Users\shail\AppData\Local\Temp\ipykernel_4288\564963302.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(train_data,
# Epoch 1/30
# 10/10 [==============================] - ETA: 0s - loss: 12.3363 - accuracy: 0.1969
# Epoch 1: val_accuracy improved from -inf to 0.44531, saving model to best_model.h5
# 10/10 [==============================] - 13s 1s/step - loss: 12.3363 - accuracy: 0.1969 - val_loss: 5.6839 - val_accuracy: 0.4453
# Epoch 2/30
# 10/10 [==============================] - ETA: 0s - loss: 5.1704 - accuracy: 0.4906
# Epoch 2: val_accuracy improved from 0.44531 to 0.74609, saving model to best_model.h5
# 10/10 [==============================] - 11s 1s/step - loss: 5.1704 - accuracy: 0.4906 - val_loss: 1.6371 - val_accuracy: 0.7461
# Epoch 3/30
# 10/10 [==============================] - ETA: 0s - loss: 2.3056 - accuracy: 0.6906
# Epoch 3: val_accuracy improved from 0.74609 to 0.86719, saving model to best_model.h5
# 10/10 [==============================] - 11s 1s/step - loss: 2.3056 - accuracy: 0.6906 - val_loss: 0.7740 - val_accuracy: 0.8672
# Epoch 4/30
# 10/10 [==============================] - ETA: 0s - loss: 1.1055 - accuracy: 0.8208
# Epoch 4: val_accuracy improved from 0.86719 to 0.91797, saving model to best_model.h5
# 10/10 [==============================] - 10s 1s/step - loss: 1.1055 - accuracy: 0.8208 - val_loss: 0.3057 - val_accuracy: 0.9180
# Epoch 5/30
# 10/10 [==============================] - ETA: 0s - loss: 0.5161 - accuracy: 0.9182
# Epoch 5: val_accuracy improved from 0.91797 to 0.95312, saving model to best_model.h5
# 10/10 [==============================] - 10s 1s/step - loss: 0.5161 - accuracy: 0.9182 - val_loss: 0.2049 - val_accuracy: 0.9531
# Epoch 6/30
# 10/10 [==============================] - ETA: 0s - loss: 0.4318 - accuracy: 0.9088
# Epoch 6: val_accuracy improved from 0.95312 to 0.96484, saving model to best_model.h5
# 10/10 [==============================] - 10s 1s/step - loss: 0.4318 - accuracy: 0.9088 - val_loss: 0.2077 - val_accuracy: 0.9648
# Epoch 7/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1836 - accuracy: 0.9528
# Epoch 7: val_accuracy improved from 0.96484 to 0.98438, saving model to best_model.h5
# 10/10 [==============================] - 10s 1s/step - loss: 0.1836 - accuracy: 0.9528 - val_loss: 0.0680 - val_accuracy: 0.9844
# Epoch 8/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1699 - accuracy: 0.9560
# Epoch 8: val_accuracy did not improve from 0.98438
# 10/10 [==============================] - 10s 1s/step - loss: 0.1699 - accuracy: 0.9560 - val_loss: 0.1261 - val_accuracy: 0.9648
# Epoch 9/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1589 - accuracy: 0.9591
# Epoch 9: val_accuracy improved from 0.98438 to 0.98828, saving model to best_model.h5
# 10/10 [==============================] - 10s 1s/step - loss: 0.1589 - accuracy: 0.9591 - val_loss: 0.0215 - val_accuracy: 0.9883
# Epoch 10/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1694 - accuracy: 0.9591
# Epoch 10: val_accuracy improved from 0.98828 to 0.99219, saving model to best_model.h5
# 10/10 [==============================] - 10s 1s/step - loss: 0.1694 - accuracy: 0.9591 - val_loss: 0.0187 - val_accuracy: 0.9922
# Epoch 11/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0657 - accuracy: 0.9811
# Epoch 11: val_accuracy improved from 0.99219 to 0.99609, saving model to best_model.h5
# 10/10 [==============================] - 10s 1s/step - loss: 0.0657 - accuracy: 0.9811 - val_loss: 0.0057 - val_accuracy: 0.9961
# Epoch 12/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0430 - accuracy: 0.9811
# Epoch 12: val_accuracy did not improve from 0.99609
# 10/10 [==============================] - 10s 1s/step - loss: 0.0430 - accuracy: 0.9811 - val_loss: 0.0214 - val_accuracy: 0.9922
# Epoch 13/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0728 - accuracy: 0.9811
# Epoch 13: val_accuracy did not improve from 0.99609
# 10/10 [==============================] - 10s 1s/step - loss: 0.0728 - accuracy: 0.9811 - val_loss: 0.0113 - val_accuracy: 0.9922
# Epoch 14/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9906
# Epoch 14: val_accuracy improved from 0.99609 to 1.00000, saving model to best_model.h5
# 10/10 [==============================] - 10s 1s/step - loss: 0.0223 - accuracy: 0.9906 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 15/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9969
# Epoch 15: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 10s 1s/step - loss: 0.0067 - accuracy: 0.9969 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 16/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0400 - accuracy: 0.9874
# Epoch 16: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 10s 1s/step - loss: 0.0400 - accuracy: 0.9874 - val_loss: 0.0055 - val_accuracy: 0.9961
# Epoch 16: early stopping

# %%
# Loading the best fit model 
from keras.models import load_model
model = load_model("./best_model.h5")

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
# just to map o/p values 
op = dict(zip( train_data.class_indices.values(), train_data.class_indices.keys()))

# %%
# path for the image to see if it predics correct class

path = "./train/angry/images (11).jpg"
img = load_img(path, target_size=(224,224) )

i = img_to_array(img)/255
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

print(f" the image is of {op[pred]}")

# to display the image  
plt.imshow(input_arr[0])
plt.title("input image")
plt.show()
# Out:
# 1/1 [==============================] - 0s 354ms/step
#  the image is of Angry
